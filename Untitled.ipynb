# %%
import os
import leafmap
import torch
from samgeo import SamGeo, tms_to_geotiff, get_basemaps
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [1], line 3
#       1 import os
#       2 import leafmap
# ----> 3 import torch
#       4 from samgeo import SamGeo, tms_to_geotiff, get_basemaps
#
# ModuleNotFoundError: No module named 'torch'

# %%
pip list
# Out:
# Package                       VersionNote: you may need to restart the kernel to use updated packages.
#
# ----------------------------- ------------
# access                        1.1.8
# aenum                         3.1.11
# affine                        2.3.1
# aiobotocore                   2.4.0
# aiohttp                       3.8.3
# aioitertools                  0.11.0
# aiosignal                     1.3.1
# alabaster                     0.7.12
# altair                        4.1.0
# amply                         0.1.5
# aniso8601                     9.0.1
# anyio                         3.6.2
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# asciitree                     0.3.3
# astor                         0.8.1
# asttokens                     2.1.0
# async-timeout                 4.0.2
# attrs                         22.1.0
# aws-requests-auth             0.4.2
# Babel                         2.11.0
# ...
